# %%
# %load_ext autoreload
# %autoreload 2
from lexicon import *
from yast import *

# %%
reset()
s = """
liegen (Perfekt)
  nachts
  in: Mondschein (Definit)
  auf: Blatt (Indefinit)
  Liegende: Ei (Indefinit)
    klein

herausschlüpfen (Präteritum)
  als: aufgehen (Präteritum)
    an: Sonntagmorgen (Indefinit)
      schön
    Aufgehende: Sonne (Definit)
  aus: Ei (Definit + Voll)
  knack
  Herausschlüpfende: Raupe (Indefinit)
    klein
    hungrig

machen (Präteritum)
  dann
  Machende: Raupe
  auf: Weg (Definit + Bewegung)
  um: suchen (Infinit)
    Gesuchte: Futter

fressen (Präteritum + ReflexivBewegungsart)
  an: Montag (Definit)
  Fressende: Raupe
  Richtung: Apfel (Indefinit)
    in: Korb (Definit)
      auf: Theke (Definit)
  aber: satt (sein + Vorn)
    Seinde: Raupe
    noch
    immer
    nicht

schlimm (sein + Präteritum)
  Seinde: verspüren (Infinit)
    Verspürende: Bauchschmerzen

anfertigen (Präteritum + Benefaktivdativ)
  Anfertigende: Raupe
  Benefaktor: Raupe
  Angefertigte: Haus (Indefinit)
    eng
  nennen (Präsens)
    Genannte: Haus
    Nennende: 0 (Belebt)
    Namen: Kokon
      Raupe (Definit + Voll)

bleiben (Präteritum)
  in: Haus (Definit + Voll)
    bauen (Zustandspassiv + Infinit)
      Bauende: Raupe
  Bleibende: Raupe
  Woche (Numerale: zwei + Plural)
    lang
"""
Syntax(s)
# Out:
# Nachts hat in dem Mondschein auf einem Blatt ein kleines Ei gelegen.
# Als an einem schönen Sonntagmorgen die Sonne aufging schlüpfte aus dem Ei knack eine kleine hungrige Raupe heraus.
# Dann machte sie sich auf den Weg um Futter zu suchen.
# An dem Montag fraß sie sich durch einen Apfel in dem Korb auf der Theke aber satt war sie noch immer nicht.
# Bauchschmerzen zu verspüren war schlimm.
# Ich fertigte mir ein enges Haus andas jemand Kokon der Raupe nennt.
# In dem von ihr gebauten Haus blieb sie zwei lange Wochen.

# %%
reset()
s = """
liegen (Präteritum)
  nachts
  in: Mondschein (Definit)
  auf: Blatt (Indefinit)
  Liegende: Ei (Indefinit)
    klein
"""
Syntax(s, xml = True)
# Out:
# Nachts lag in dem Mondschein auf einem Blatt ein kleines Ei.
# =====
# <SATZ kind="Wurzel" tense="Präsens">
#   <SATZ kind="Hauptsatz" tense="Präteritum">
#     <VORFELD>
#       <ADVERBIALE>
#         <ADVERB>nachts</ADVERB>
#       </ADVERBIALE>
#     </VORFELD>
#     <VERBZWEIT>
#       <FINITUM verb="liegen" tense="Präteritum" person="3" number="Singular">lag</FINITUM>
#     </VERBZWEIT>
#     <ADVERBIALE>
#       <JUNKTOR>in</JUNKTOR>
#       <PHRASE case="Dativ">
#         <DETERMINATIV>
#           <ARTIKEL>dem</ARTIKEL>
#         </DETERMINATIV>
#         <REFERENT>Mondschein</REFERENT>
#       </PHRASE>
#     </ADVERBIALE>
#     <ADVERBIALE>
#       <JUNKTOR>auf</JUNKTOR>
#       <PHRASE case="Dativ">
#         <DETERMINATIV>
#           <ARTIKEL>einem</ARTIKEL>
#         </DETERMINATIV>
#         <REFERENT>Blatt</REFERENT>
#       </PHRASE>
#     </ADVERBIALE>
#     <ARGUMENT role="Liegende" case="Nominativ">
#       <PHRASE case="Nominativ">
#         <DETERMINATIV>
# ...
